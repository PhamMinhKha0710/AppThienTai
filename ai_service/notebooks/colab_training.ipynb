# %% [markdown]
# # 🌩️ App Thien Tai - AI Service Training
#
# This notebook allows you to train all AI models for the App Thien Tai project directly on Google Colab.
#
# **Models included:**
# 1. **Hazard Predictor**: Predicts disaster risk (flood, storm, landslide).
# 2. **Weather Forecaster**: Predicts next-day weather (temp, rain, humidity).
# 3. **Alert Scorer**: Scores priority of alerts.
# 4. **Notification Timing**: Optimizes notification send times.
# 5. **Duplicate Detector**: Detects duplicate reports.

# %% [markdown]
# ## 1. Setup Environment
# Upload your `ai_service` folder to your Google Drive first for persistence, or upload the zip file here.

# %%
# Mount Google Drive if your code is there
from google.colab import drive
drive.mount('/content/drive')

# Change this path to where your 'ai_service' folder is located
# %cd /content/drive/MyDrive/AppThienTai/ai_service
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Mount Google Drive if your code is there
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#       5 # Change this path to where your 'ai_service' folder is located
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# Install dependencies
# !pip install -r requirements.txt
# !pip install xgboost lightgbm scikit-learn pandas numpy joblib matplotlib seaborn

# %% [markdown]
# ## 2. Train All Models
# Run the master training script.

# %%
# !python scripts/train_all.py

# %% [markdown]
# ## 3. Verify Models
# Check if models were created successfully.

# %%
# !ls -lh data/models/

# %% [markdown]
# ## 4. Download Trained Models
# If you are not using Google Drive sync, run this to download the models to your local machine.

# %%
from google.colab import files
# !zip -r trained_models.zip data/models/
files.download('trained_models.zip')
